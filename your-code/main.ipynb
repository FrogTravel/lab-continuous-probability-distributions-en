# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def generate(bottom, ceiling, count):
    return np.random.uniform(low=bottom, high=ceiling, size=count)

# %%
dist_un_1 = generate(10, 15, 100)

# %%
dist_un_2 = generate(10, 60, 1000)

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1,2)
ax1.hist(dist_un_1, bins=5)
ax1.set(xlabel="Value", ylabel="Count")

ax2.hist(dist_un_2, bins=10)
ax2.set(xlabel="Value")
# Out:
# [Text(0.5, 0, 'Value')]

# %% [markdown]
# How are the two distributions different?

# %%
# On the right distribution, because it has more values we clearly see that it is uniform distribution

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def generate_norm(count, avg, std):
    rvs = norm.rvs(size=count, loc=avg, scale=std)
    return rvs

# %%
q1 = generate_norm(1000, 10, 1)
q1
# Out:
# array([10.81030587, 11.5778555 ,  9.94020773,  9.74978219, 11.04520194,
#        10.93250501, 10.83683039, 10.68983975,  9.56222971, 11.34937017,
#        10.53090238, 10.32121675, 10.6808023 , 11.82007109,  9.31781444,
#        10.40063768, 10.5048316 ,  8.61897583, 10.49715997,  9.68020452,
#        10.60778973, 10.98433659,  9.35513853,  9.4689754 , 10.33100298,
#        10.27204479,  8.92848911,  9.70360052, 10.307427  ,  9.73667775,
#         9.49586009,  9.51507168,  9.37323257,  8.22723485, 10.61084384,
#        11.03889956, 10.29897287, 11.15702475, 10.43668336, 12.53226309,
#         9.9022957 , 10.23009774, 10.65490721, 11.36195097,  9.98106065,
#         9.52702213, 11.26933931,  8.81387869,  9.52983981, 10.85933045,
#        10.48431742, 10.83884689, 10.49576514,  9.65717294, 10.44664898,
#         9.28399393,  9.75689008, 10.48691468, 10.07613007, 12.07064383,
#        11.48559678, 10.85712549,  8.87716889,  9.89554788,  9.42780912,
# ...

# %%
q2 = generate_norm(1000, 10, 50)
q2
# Out:
# array([ 3.43318962e+00, -2.41131373e+01,  3.85362255e+01,  5.53730357e+00,
#         1.86878557e+01,  8.02781227e+01,  7.66631863e+01, -4.93335400e+01,
#         2.34387567e+01,  5.72419008e+00, -6.05017366e+01,  2.14007559e+00,
#         6.80946332e+01,  7.52004880e+01,  9.10897085e+00,  1.53363268e+01,
#        -5.10358806e+01, -8.88890234e+01, -1.90492946e+01, -2.96581938e+01,
#         3.96710071e+01, -4.50980653e+01, -3.94737604e+00, -4.73883838e+01,
#        -2.18053615e+01, -4.67396920e+01, -4.78294619e+01, -4.12116958e+01,
#        -3.62492267e+00,  3.39727266e+01,  1.06574785e+02,  5.23721976e+01,
#         1.29007909e+00, -4.79811161e+01,  9.89087701e+00, -2.59566210e+01,
#        -2.57255433e+01, -6.06935797e+01, -2.83646468e+01, -3.08115293e+01,
#         1.51428073e+02, -1.94150240e+01,  4.91310146e+01,  5.12244682e+01,
#         9.39330170e+00,  3.02062929e+00, -6.12344549e+01,  2.96010232e+01,
# ...

# %%
fig, ax = plt.subplots(1, 2, sharey=True)
fig.suptitle("Gaussian Distribution")

ax[0].hist(q1, bins = 100)
ax[0].set(xlabel="Value", ylabel="Count")

ax[1].hist(q2, bins = 100)
ax[1].set(xlabel="Value")
# Out:
# [Text(0.5, 0, 'Value')]

# %% [markdown]
# How are the two distributions different?

# %%
# The left distribution is has lower std, then the right. The right is more leptokurtic. The both are not unit

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
import pandas as pd


data = pd.read_csv("vehicles.csv")
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
sns.histplot(data["Fuel Barrels/Year"])
# Out:
# <Axes: xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(data["CO2 Emission Grams/Mile"])
# Out:
# <Axes: xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(data["Combined MPG"])
# Out:
# <Axes: xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
df1 = data["Fuel Barrels/Year"]

print(f"{df1.mode() - df1.median() - df1.mean()}")
# Out:
# 0   -16.645284
# Name: Fuel Barrels/Year, dtype: float64

# %%
df2 = data["CO2 Emission Grams/Mile"]

print(f"{df2.mode() - df2.median() - df2.mean()}")
# Out:
# 0   -449.330959
# Name: CO2 Emission Grams/Mile, dtype: float64

# %%
df3 = data["Combined MPG"]

print(f"{df3.mode() - df3.median() - df3.mean()}")
# Out:
# 0   -20.929322
# Name: Combined MPG, dtype: float64

# %%
# The Fuel Barrels/Year is more normally distributed. However it is still positively skewed

# %%
from scipy.stats import shapiro

for name, series in [("Fuel Barrels/Year", df1), ("CO2 Emission Grams/Mile", df2), ("Combined MPG", df3)]:
    stat, p = shapiro(series)
    conclusion = "likely normal" if p > 0.05 else "not normal"
    print(f"{name}: W={stat:.4f}, p={p:.4e} → {conclusion} (α=0.05)")
# Out:
# Fuel Barrels/Year: W=0.9675, p=1.1614e-64 → not normal (α=0.05)
# CO2 Emission Grams/Mile: W=0.9676, p=1.2676e-64 → not normal (α=0.05)
# Combined MPG: W=0.9466, p=3.5259e-75 → not normal (α=0.05)
# /opt/anaconda3/envs/ironhack_prework/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:592: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 35952.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def generate_exp(count, scale):
    rng = np.random.default_rng()
    return rng.exponential(scale=scale, size=count)

# %%
dist1 = generate_exp(10, 10)
dist2 = generate_exp(100, 100)

fig, ax = plt.subplots(1, 2, sharey=True)
fig.suptitle("Exponential Distribution")

ax[0].hist(dist1, bins=100)
ax[0].set(xlabel="Value", ylabel="Count")

ax[1].hist(dist2, bins=100)
ax[1].set(xlabel="Value")
# Out:
# [Text(0.5, 0, 'Value')]

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well. The distribution with the bigger mean streads more

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

prob = expon.cdf(15, scale=10)
prob
# Out:
# np.float64(0.7768698398515702)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1-prob
# Out:
# np.float64(0.2231301601484298)
